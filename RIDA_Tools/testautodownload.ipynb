# %%
from sentinelsat import SentinelAPI
from datetime import date

username = 'Desukaz.skrr@gmail.com'
password = 'IMDSK7901Desuka!'
api = SentinelAPI(username, password, 'https://apihub.copernicus.eu/dhus', timeout=120)
# api = SentinelAPI(username, password, 'https://scihub.copernicus.eu/dhus', timeout=120)
# api = SentinelAPI(username, password, 'https://dataspace.copernicus.eu/apihub/', timeout=120)
tile_id = 'T47QNB'  

start_date = '20220101'
end_date = '20230131'

products = api.query(area=f'{tile_id}',
                     date=(start_date, end_date), 
                     platformname='Sentinel-2',
                     cloudcoverpercentage=(0, 30))  

save_directory = './downloaded_products/'

for product_id in products:
    api.download(product_id, directory_path=save_directory)

print("Download completed!")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/anaconda3/envs/RIDA_env/lib/python3.9/site-packages/urllib3/connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File ~/anaconda3/envs/RIDA_env/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...
